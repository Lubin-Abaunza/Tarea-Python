# %% [markdown]
# # Solución

# %% [markdown]
# **1.** Revise todas las lecciones de programación en Python.

# %% [markdown]
# ¡Listo!

# %% [markdown]
# **2.** Escriba un cuaderno que contenga dos ejercicios propuestos y resueltos de colecciones, en los cuales utilice los diferentes métodos asociados a cada tipo de colección.

# %% [markdown]
# * **Ejercicio 1**
#
# Defina un diccionario de al menos 4 llaves de tal manera que esas llaves sean tuplas. Acceda a cada elemento. ¿Puede hacer lo mismo para una llave que sea definida como lista o diccionario?

# %%
# Diccionario

Col_animales = {("Perros","Gatos"):["Blancos","Negros","Cafes","etc"],
                ("Peces","Aves"):["Amarillos","Azules","Verdes","etc"],
                ("Insectos","Crustáceos"):["Negros","Cafes","Amarillos","Naranja","Verdes","etc"],
                ("Serpients","Lagartos","Anfibios"):["Verdes","Cafes","Negros"]}

print(Col_animales)
# Out:
# {('Perros', 'Gatos'): ['Blancos', 'Negros', 'Cafes', 'etc'], ('Peces', 'Aves'): ['Amarillos', 'Azules', 'Verdes', 'etc'], ('Insectos', 'Crustáceos'): ['Negros', 'Cafes', 'Amarillos', 'Naranja', 'Verdes', 'etc'], ('Serpients', 'Lagartos', 'Anfibios'): ['Verdes', 'Cafes', 'Negros']}

# %%
# Acceso a cada elemento

print(Col_animales[("Perros","Gatos")][0])
print(Col_animales[("Perros","Gatos")][1])
print(Col_animales[("Perros","Gatos")][2])
print(Col_animales[("Perros","Gatos")][3])
print('\n')


print(Col_animales[("Peces","Aves")][0])
print(Col_animales[("Peces","Aves")][1])
print(Col_animales[("Peces","Aves")][2])
print(Col_animales[("Peces","Aves")][3])
print('\n')

print(Col_animales[("Insectos","Crustáceos")][0])
print(Col_animales[("Insectos","Crustáceos")][1])
print(Col_animales[("Insectos","Crustáceos")][2])
print(Col_animales[("Insectos","Crustáceos")][3])
print(Col_animales[("Insectos","Crustáceos")][4])
print(Col_animales[("Insectos","Crustáceos")][5])
print('\n')

print(Col_animales[("Serpients","Lagartos","Anfibios")][0])
print(Col_animales[("Serpients","Lagartos","Anfibios")][1])
print(Col_animales[("Serpients","Lagartos","Anfibios")][2])
print('\n')
# Out:
# Blancos
# Negros
# Cafes
# etc
#
#
# Amarillos
# Azules
# Verdes
# etc
#
#
# Negros
# Cafes
# Amarillos
# Naranja
# Verdes
# etc
#
#
# Verdes
# Cafes
# Negros

# %%
Col_animales = {["Perros","Gatos"]:["Bancos","Negros","Cafes","etc"],
                ["Peces","Aves"]:["Amarillos","Azules","Verdes","etc"],
                ["Insectos","Crustáceos"]:["Negros","Cafes","Amarillos","Naranja","Verdes","etc"],
                ["Serpients","Lagartos","Anfibios"]:["Verdes","Cafes","Negros"]}

print(Col_animales)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 Col_animales = {["Perros","Gatos"]:["Bancos","Negros","Cafes","etc"],
#       2                 ["Peces","Aves"]:["Amarillos","Azules","Verdes","etc"],
#       3                 ["Insectos","Crustáceos"]:["Negros","Cafes","Amarillos","Naranja","Verdes","etc"],
#       4                 ["Serpients","Lagartos","Anfibios"]:["Verdes","Cafes","Negros"]}
#       6 print(Col_animales)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# Las llaves no se pueden defimir como listas

# %%
Col_animales = {{"Perros","Gatos"}:["Bancos","Negros","Cafes","etc"],
                {"Peces","Aves"}:["Amarillos","Azules","Verdes","etc"],
                {"Insectos","Crustáceos"}:["Negros","Cafes","Amarillos","Naranja","Verdes","etc"],
                {"Serpients","Lagartos","Anfibios"}:["Verdes","Cafes","Negros"]}

print(Col_animales)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 Col_animales = {{"Perros","Gatos"}:["Bancos","Negros","Cafes","etc"],
#       2                 {"Peces","Aves"}:["Amarillos","Azules","Verdes","etc"],
#       3                 {"Insectos","Crustáceos"}:["Negros","Cafes","Amarillos","Naranja","Verdes","etc"],
#       4                 {"Serpients","Lagartos","Anfibios"}:["Verdes","Cafes","Negros"]}
#       6 print(Col_animales)
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# Las llaves no se pueden defimir como dicccionario

# %% [markdown]
# * **Ejercicio 2**
#
# ¿Qué significa default?

# %% [markdown]
# La enciclopedia libre (Wikipedia) define default como:
#
# *"Un valor o configuración por defecto (default, en inglés) en informática se refiere al valor preexistente (predeterminado) de una configuración o ajuste configurable por el usuario que se asigna a una aplicación de software, programa de ordenador o dispositivo. Dichas configuraciones también se denominan preajustes (presets, en inglés) o ajustes de fábrica, especialmente para dispositivos electrónicos.*

# %% [markdown]
# **3.** Escriba un archivo de excel o csv con la información de cuentas bancarias que contiene la siguiente información: número de cuenta, nombre del cliente, saldo_actual, fecha última transacción. Coloque el archivo en alguna dirección url. Por ejemplo en su repositorio de Github.

# %% [markdown]
# ¡Listo!, el archivo se llama Cuentas bancarias.xlsx

# %% [markdown]
# **4** Escriba un cuadernos en donde implemente  una clase  iterable  que haga lo siguiente:
#
# a) Al inicio abra el archivo y lo suba a un dataframe de Pandas.

# %%
import pandas as pd
import numpy as np

# %%
basepath= "C:/Users/labau/OneDrive/Escritorio"
archibo=basepath + "/Cuentas bancarias.xlsx"
dfcuentas = pd.read_excel(archibo,sheet_name = "Lista")

# %%
dfcuentas
# Out:
#     Número de cuenta                 Nombre del cliente  Saldo_actual  \
# 0            1014309      ABELLA HERRERA WILLIAM EFRAIN  3.175000e+06
# 1            1245378                 ACOSTA FAUSTO JOSE  1.930450e+06
# 2            1476447                   ACOSTA PEREGRINO  2.685900e+06
# 3            1707516         ACOSTA ARAGON MARIA AMPARO  3.441350e+06
# 4            1938585         BRAVO ELVIRA JOSE FERNANDO  4.196800e+06
# 5            2169654      BUCHELI QUINA MONICA DEL PILA  2.952250e+06
# 6            2400723        BURBANO CASTRO EDWIN NESTOR  5.707700e+06
# 7            2631792      BUSTOS RENGIFO FREDDY WILLIAN  6.463150e+06
# 8            2862861     CAICEDO ALZATE CLAUDIA CECILIA  7.218600e+06
# 9            3093930             CAICEDO CALVACHE DAIRA  7.140716e+06
# 10           3324999             CAMACHO VELASCO ALIRIO  7.729500e+06
# 11           3556068          ERAZO RIVERA JOSE ESTEBAN  8.318283e+06
# 12           3787137                 ESCOBAR LUIS JAIME  8.907066e+06
# 13           4018206    ESCOBAR CANENCIO AMANDA BEATRIZ  3.495850e+06
# 14           4249275               ESCOBAR SOLIS STELLA  1.108463e+07
# 15           4480344   ESTRADA DE JIMENEZ LILIA MARLENE  1.067342e+07
# 16           4711413  EUSCATEGUI PACHON ROBERTH ALFREDO  1.262200e+06
# 17           4942482                   FERNANDEZ MARINO  1.850983e+06
# 18           5173551           FERNANDEZ LOPEZ GILBERTO  2.439766e+06
